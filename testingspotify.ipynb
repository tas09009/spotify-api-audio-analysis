# %%
import spotipy
import spotipy.util as sp_util
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOauthError
from spotipy.client import SpotifyException
from pprint import pprint
# from album_list_conv.py import (album_id)


def authenticate_client():
    client_credentials = SpotifyClientCredentials()
    spotify = spotipy.Spotify(client_credentials_manager=client_credentials)
    return spotify


spotify = authenticate_client()
results = spotify.search('Queen')
tracks = results.get('tracks', {}).get('items', [])




############################################################################

def track_string(track):
    """
    Given a track, return a string describing the track:
    Track Name - Artist1, Artist2, etc...
    :param track:
    :return: A string describing the track
    """
    track_name = track.get('name')
    artist_names = ', '.join([artist.get('name') for artist in track.get('artists', [])])
    return '{} - {}'.format(track_name, artist_names)

############################################################################

def translate_key_to_pitch(key):
    """
    Given a Key value in Pitch Class Notation, map the key to its actual pitch string
    https://en.wikipedia.org/wiki/Pitch_class
    :param key: The integer key
    :return: The translated Pitch Class string
    """
    pitches = ['C', 'C/D', 'D', 'D/E', 'E', 'F', 'F/G', 'G', 'G/A', 'A', 'A/B', 'B']
    return pitches[key]

############################################################################
def print_audio_features_for_track(track, track_features):
    """
    Given a track and a features response, print out the desired audio features for that track
    :param track:
    :param track_features:
    :return:
    """
    desired_features = [
        'tempo',
        'time_signature',
        'key',
        'mode',
        'loudness',
        'energy',
        'danceability',
        'acousticness',
        'instrumentalness',
        'liveness',
        'speechiness',
        'valence'
    ]

    print('\n  {}'.format(track_string(track)))
    for feature in desired_features:
        # Pull out the value of the feature from the features
        feature_value = track_features.get(feature)

        # If this feature is the key, convert it to a readable pitch
        if feature == 'key':
            feature_value = translate_key_to_pitch(feature_value)

        # Print the feature value
        print('    {}: {}'.format(feature, feature_value))

####################################################################################

def get_audio_features(spotify, tracks, pretty_print=False):
    """
    Given a list of tracks, get and print the audio features for those tracks!
    :param spotify: An authenticated Spotipy instance
    :param tracks: A list of track dictionaries
    """
    if not tracks:
        print('No tracks provided.')
        return

    # Build a map of id->track so we can get the full track info later
    track_map = {track.get('id'): track for track in tracks}
        
    
    
    # Request the audio features for the chosen tracks (limited to 50)
#     print_header('Getting Audio Features...')
    tracks_features_response = spotify.audio_features(tracks=track_map.keys())
    track_features_map = {f.get('id'): f for f in tracks_features_response}
    pprint(track_features_map)

    # Iterate through the features and print the track and info
    if pretty_print:
        for track_id, track_features in track_features_map.items():
    # Print out the track info and audio features
            track = track_map.get(track_id)
            print_audio_features_for_track(track, track_features)
    return track_features_map

get_audio_features(spotify, tracks, pretty_print=False)

#####################################################################################

#for track in tracks:
#    if (track['name'] == 'Bohemian Rhapsody - 2011 Mix'):
#        my_id = track['id']

#print (my_id)
# Out:
# {'0ExiKxfY5rHBW06TcV1xXU': {'acousticness': 0.0703,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ExiKxfY5rHBW06TcV1xXU',
#                             'danceability': 0.658,
#                             'duration_ms': 185587,
#                             'energy': 0.695,
#                             'id': '0ExiKxfY5rHBW06TcV1xXU',
#                             'instrumentalness': 0,
#                             'key': 0,
#                             'liveness': 0.13,
#                             'loudness': -5.499,
#                             'mode': 1,
#                             'speechiness': 0.0279,
#                             'tempo': 133.949,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/0ExiKxfY5rHBW06TcV1xXU',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:0ExiKxfY5rHBW06TcV1xXU',
#                             'valence': 0.571},
#  '11IzgLRXV7Cgek3tEgGgjw': {'acousticness': 0.422,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11IzgLRXV7Cgek3tEgGgjw',
#                             'danceability': 0.671,
#                             'duration_ms': 248440,
#                             'energy': 0.711,
#                             'id': '11IzgLRXV7Cgek3tEgGgjw',
#                             'instrumentalness': 0,
#                             'key': 2,
#                             'liveness': 0.104,
#                             'loudness': -7.813,
#                             'mode': 1,
#                             'speechiness': 0.0478,
#                             'tempo': 113.809,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/11IzgLRXV7Cgek3tEgGgjw',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:11IzgLRXV7Cgek3tEgGgjw',
#                             'valence': 0.466},
#  '2lxW8vQ9Qjv0qeSQiIBOKJ': {'acousticness': 0.22,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lxW8vQ9Qjv0qeSQiIBOKJ',
#                             'danceability': 0.781,
#                             'duration_ms': 224707,
#                             'energy': 0.619,
#                             'id': '2lxW8vQ9Qjv0qeSQiIBOKJ',
#                             'instrumentalness': 0,
#                             'key': 7,
#                             'liveness': 0.112,
#                             'loudness': -6.616,
#                             'mode': 1,
#                             'speechiness': 0.0882,
#                             'tempo': 82.954,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/2lxW8vQ9Qjv0qeSQiIBOKJ',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:2lxW8vQ9Qjv0qeSQiIBOKJ',
#                             'valence': 0.391},
#  '4o05DiC0RQ9DNtGJGauwna': {'acousticness': 0.248,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4o05DiC0RQ9DNtGJGauwna',
#                             'danceability': 0.543,
#                             'duration_ms': 189397,
#                             'energy': 0.787,
#                             'id': '4o05DiC0RQ9DNtGJGauwna',
#                             'instrumentalness': 0,
#                             'key': 8,
#                             'liveness': 0.0778,
#                             'loudness': -6.52,
#                             'mode': 1,
#                             'speechiness': 0.241,
#                             'tempo': 173.702,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/4o05DiC0RQ9DNtGJGauwna',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:4o05DiC0RQ9DNtGJGauwna',
#                             'valence': 0.343},
#  '52WTLETEHs5jwCr7LCq0VW': {'acousticness': 0.211,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52WTLETEHs5jwCr7LCq0VW',
#                             'danceability': 0.418,
#                             'duration_ms': 230720,
#                             'energy': 0.547,
#                             'id': '52WTLETEHs5jwCr7LCq0VW',
#                             'instrumentalness': 0.0443,
#                             'key': 1,
#                             'liveness': 0.187,
#                             'loudness': -4.932,
#                             'mode': 1,
#                             'speechiness': 0.0295,
#                             'tempo': 131.99,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/52WTLETEHs5jwCr7LCq0VW',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:52WTLETEHs5jwCr7LCq0VW',
#                             'valence': 0.13},
#  '53b4d9jHQZq89EtQxwUURr': {'acousticness': 0.0186,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/53b4d9jHQZq89EtQxwUURr',
#                             'danceability': 0.617,
#                             'duration_ms': 160444,
#                             'energy': 0.463,
#                             'id': '53b4d9jHQZq89EtQxwUURr',
#                             'instrumentalness': 0,
#                             'key': 11,
#                             'liveness': 0.187,
#                             'loudness': -7.978,
#                             'mode': 0,
#                             'speechiness': 0.0402,
#                             'tempo': 83.931,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/53b4d9jHQZq89EtQxwUURr',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:53b4d9jHQZq89EtQxwUURr',
#                             'valence': 0.24},
#  '54flyrjcdnQdco7300avMJ': {'acousticness': 0.679,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54flyrjcdnQdco7300avMJ',
#                             'danceability': 0.693,
#                             'duration_ms': 122067,
#                             'energy': 0.497,
#                             'id': '54flyrjcdnQdco7300avMJ',
#                             'instrumentalness': 0,
#                             'key': 2,
#                             'liveness': 0.258,
#                             'loudness': -7.316,
#                             'mode': 1,
#                             'speechiness': 0.119,
#                             'tempo': 81.308,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/54flyrjcdnQdco7300avMJ',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:54flyrjcdnQdco7300avMJ',
#                             'valence': 0.473},
#  '57JVGBtBLCfHw2muk5416J': {'acousticness': 0.112,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57JVGBtBLCfHw2muk5416J',
#                             'danceability': 0.933,
#                             'duration_ms': 214653,
#                             'energy': 0.528,
#                             'id': '57JVGBtBLCfHw2muk5416J',
#                             'instrumentalness': 0.329,
#                             'key': 5,
#                             'liveness': 0.163,
#                             'loudness': -6.472,
#                             'mode': 0,
#                             'speechiness': 0.162,
#                             'tempo': 109.975,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/57JVGBtBLCfHw2muk5416J',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:57JVGBtBLCfHw2muk5416J',
#                             'valence': 0.756},
#  '7hQJA50XrCWABAu5v6QZ4i': {'acousticness': 0.0472,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hQJA50XrCWABAu5v6QZ4i',
#                             'danceability': 0.563,
#                             'duration_ms': 209413,
#                             'energy': 0.865,
#                             'id': '7hQJA50XrCWABAu5v6QZ4i',
#                             'instrumentalness': 0.000191,
#                             'key': 5,
#                             'liveness': 0.77,
#                             'loudness': -5.277,
#                             'mode': 1,
#                             'speechiness': 0.16,
#                             'tempo': 156.271,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/7hQJA50XrCWABAu5v6QZ4i',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:7hQJA50XrCWABAu5v6QZ4i',
#                             'valence': 0.601},
#  '7tFiyTwD0nx5a1eklYtX2J': {'acousticness': 0.288,
#                             'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tFiyTwD0nx5a1eklYtX2J',
#                             'danceability': 0.392,
#                             'duration_ms': 354320,
#                             'energy': 0.402,
#                             'id': '7tFiyTwD0nx5a1eklYtX2J',
#                             'instrumentalness': 0,
#                             'key': 0,
#                             'liveness': 0.243,
#                             'loudness': -9.961,
#                             'mode': 0,
#                             'speechiness': 0.0536,
#                             'tempo': 143.883,
#                             'time_signature': 4,
#                             'track_href': 'https://api.spotify.com/v1/tracks/7tFiyTwD0nx5a1eklYtX2J',
#                             'type': 'audio_features',
#                             'uri': 'spotify:track:7tFiyTwD0nx5a1eklYtX2J',
#                             'valence': 0.228}}
# {'4o05DiC0RQ9DNtGJGauwna': {'danceability': 0.543,
#   'energy': 0.787,
#   'key': 8,
#   'loudness': -6.52,
#   'mode': 1,
#   'speechiness': 0.241,
#   'acousticness': 0.248,
#   'instrumentalness': 0,
#   'liveness': 0.0778,
#   'valence': 0.343,
#   'tempo': 173.702,
#   'type': 'audio_features',
#   'id': '4o05DiC0RQ9DNtGJGauwna',
#   'uri': 'spotify:track:4o05DiC0RQ9DNtGJGauwna',
#   'track_href': 'https://api.spotify.com/v1/tracks/4o05DiC0RQ9DNtGJGauwna',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4o05DiC0RQ9DNtGJGauwna',
#   'duration_ms': 189397,
#   'time_signature': 4},
#  '0ExiKxfY5rHBW06TcV1xXU': {'danceability': 0.658,
#   'energy': 0.695,
#   'key': 0,
#   'loudness': -5.499,
#   'mode': 1,
#   'speechiness': 0.0279,
#   'acousticness': 0.0703,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.571,
#   'tempo': 133.949,
#   'type': 'audio_features',
#   'id': '0ExiKxfY5rHBW06TcV1xXU',
#   'uri': 'spotify:track:0ExiKxfY5rHBW06TcV1xXU',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ExiKxfY5rHBW06TcV1xXU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ExiKxfY5rHBW06TcV1xXU',
#   'duration_ms': 185587,
#   'time_signature': 4},
#  '7tFiyTwD0nx5a1eklYtX2J': {'danceability': 0.392,
#   'energy': 0.402,
#   'key': 0,
#   'loudness': -9.961,
#   'mode': 0,
#   'speechiness': 0.0536,
#   'acousticness': 0.288,
#   'instrumentalness': 0,
#   'liveness': 0.243,
#   'valence': 0.228,
#   'tempo': 143.883,
#   'type': 'audio_features',
#   'id': '7tFiyTwD0nx5a1eklYtX2J',
#   'uri': 'spotify:track:7tFiyTwD0nx5a1eklYtX2J',
#   'track_href': 'https://api.spotify.com/v1/tracks/7tFiyTwD0nx5a1eklYtX2J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tFiyTwD0nx5a1eklYtX2J',
#   'duration_ms': 354320,
#   'time_signature': 4},
#  '53b4d9jHQZq89EtQxwUURr': {'danceability': 0.617,
#   'energy': 0.463,
#   'key': 11,
#   'loudness': -7.978,
#   'mode': 0,
#   'speechiness': 0.0402,
#   'acousticness': 0.0186,
#   'instrumentalness': 0,
#   'liveness': 0.187,
#   'valence': 0.24,
#   'tempo': 83.931,
#   'type': 'audio_features',
#   'id': '53b4d9jHQZq89EtQxwUURr',
#   'uri': 'spotify:track:53b4d9jHQZq89EtQxwUURr',
#   'track_href': 'https://api.spotify.com/v1/tracks/53b4d9jHQZq89EtQxwUURr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/53b4d9jHQZq89EtQxwUURr',
#   'duration_ms': 160444,
#   'time_signature': 4},
#  '7hQJA50XrCWABAu5v6QZ4i': {'danceability': 0.563,
#   'energy': 0.865,
#   'key': 5,
#   'loudness': -5.277,
#   'mode': 1,
#   'speechiness': 0.16,
#   'acousticness': 0.0472,
#   'instrumentalness': 0.000191,
#   'liveness': 0.77,
#   'valence': 0.601,
#   'tempo': 156.271,
#   'type': 'audio_features',
#   'id': '7hQJA50XrCWABAu5v6QZ4i',
#   'uri': 'spotify:track:7hQJA50XrCWABAu5v6QZ4i',
#   'track_href': 'https://api.spotify.com/v1/tracks/7hQJA50XrCWABAu5v6QZ4i',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hQJA50XrCWABAu5v6QZ4i',
#   'duration_ms': 209413,
#   'time_signature': 4},
#  '57JVGBtBLCfHw2muk5416J': {'danceability': 0.933,
#   'energy': 0.528,
#   'key': 5,
#   'loudness': -6.472,
#   'mode': 0,
#   'speechiness': 0.162,
#   'acousticness': 0.112,
#   'instrumentalness': 0.329,
#   'liveness': 0.163,
#   'valence': 0.756,
#   'tempo': 109.975,
#   'type': 'audio_features',
#   'id': '57JVGBtBLCfHw2muk5416J',
#   'uri': 'spotify:track:57JVGBtBLCfHw2muk5416J',
#   'track_href': 'https://api.spotify.com/v1/tracks/57JVGBtBLCfHw2muk5416J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57JVGBtBLCfHw2muk5416J',
#   'duration_ms': 214653,
#   'time_signature': 4},
#  '11IzgLRXV7Cgek3tEgGgjw': {'danceability': 0.671,
#   'energy': 0.711,
#   'key': 2,
#   'loudness': -7.813,
#   'mode': 1,
#   'speechiness': 0.0478,
#   'acousticness': 0.422,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.466,
#   'tempo': 113.809,
#   'type': 'audio_features',
#   'id': '11IzgLRXV7Cgek3tEgGgjw',
#   'uri': 'spotify:track:11IzgLRXV7Cgek3tEgGgjw',
#   'track_href': 'https://api.spotify.com/v1/tracks/11IzgLRXV7Cgek3tEgGgjw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11IzgLRXV7Cgek3tEgGgjw',
#   'duration_ms': 248440,
#   'time_signature': 4},
#  '2lxW8vQ9Qjv0qeSQiIBOKJ': {'danceability': 0.781,
#   'energy': 0.619,
#   'key': 7,
#   'loudness': -6.616,
#   'mode': 1,
#   'speechiness': 0.0882,
#   'acousticness': 0.22,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.391,
#   'tempo': 82.954,
#   'type': 'audio_features',
#   'id': '2lxW8vQ9Qjv0qeSQiIBOKJ',
#   'uri': 'spotify:track:2lxW8vQ9Qjv0qeSQiIBOKJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2lxW8vQ9Qjv0qeSQiIBOKJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lxW8vQ9Qjv0qeSQiIBOKJ',
#   'duration_ms': 224707,
#   'time_signature': 4},
#  '52WTLETEHs5jwCr7LCq0VW': {'danceability': 0.418,
#   'energy': 0.547,
#   'key': 1,
#   'loudness': -4.932,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.211,
#   'instrumentalness': 0.0443,
#   'liveness': 0.187,
#   'valence': 0.13,
#   'tempo': 131.99,
#   'type': 'audio_features',
#   'id': '52WTLETEHs5jwCr7LCq0VW',
#   'uri': 'spotify:track:52WTLETEHs5jwCr7LCq0VW',
#   'track_href': 'https://api.spotify.com/v1/tracks/52WTLETEHs5jwCr7LCq0VW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52WTLETEHs5jwCr7LCq0VW',
#   'duration_ms': 230720,
#   'time_signature': 4},
#  '54flyrjcdnQdco7300avMJ': {'danceability': 0.693,
#   'energy': 0.497,
#   'key': 2,
#   'loudness': -7.316,
#   'mode': 1,
#   'speechiness': 0.119,
#   'acousticness': 0.679,
#   'instrumentalness': 0,
#   'liveness': 0.258,
#   'valence': 0.473,
#   'tempo': 81.308,
#   'type': 'audio_features',
#   'id': '54flyrjcdnQdco7300avMJ',
#   'uri': 'spotify:track:54flyrjcdnQdco7300avMJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/54flyrjcdnQdco7300avMJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54flyrjcdnQdco7300avMJ',
#   'duration_ms': 122067,
#   'time_signature': 4}}
